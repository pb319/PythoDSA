# %%
lst1 = [1,1,2,2,2,2,5]
set1 = set(lst1)

# %%
set1
# Out:
# {1, 2, 5}

# %%
print(type(set1))
# Out:
# <class 'set'>

# %%
#Class Methods 
set1.add("hi")

# %%
set1 #hence <class 'set'> is mutable
# Out:
# {1, 2, 5, 'hi'}

# %%
#Frozen Set (changes not allowed)
fset = frozenset(set1)
fset.add("bye") # Exception shows adding new values are not allowed.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 3
#       1 #Frozen Set (changes not allowed)
#       2 fset = frozenset(set1)
# ----> 3 fset.add("bye") # Exception shows adding new values are not allowed.
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
#Set Class work just similar to Mathematical Set
A = {"Ram","Sham","Jadu"}
B = {"Jadu","Madhu"}

# %%
#Let try
A & B #Intersection
A | B #Union
A - B
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Let try
# ----> 2 A & B #Intersection
#       3 A | B #Union
#       4 A - B
#
# NameError: name 'A' is not defined

# %%
set1 = {1,2,3}

# %%
x = [[2,1]]
print(type(x))
# Out:
# <class 'list'>

# %%
x = [1,2,3]
y
