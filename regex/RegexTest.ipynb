# %%
import re

# %%
text = "Pranay Biswas's phone number is 7407361220. The company called fesla earned a revenue ogf 100 million dollars in FY24.The General Manager, Akash's number is (991)-885-741"

# %%
pattern = "\(\d{3}\)-\d{3}-\d{3}|\d{10}"

# %%
matches = re.findall(pattern,text)
print(matches)
# Out:
# ['7407361220', '(991)-885-741']
